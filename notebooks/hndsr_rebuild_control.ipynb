# %% [markdown]
# # HNDSR Rebuild Control Notebook
#
# This notebook is a control surface for the isolated research track. Training logic lives in scripts, not in cells.

# %% [markdown]
# ## Runtime Checklist
#
# - Confirm the paper dataset paths in `configs/base.yaml`
# - Confirm W&B login if online tracking is expected
# - Run the paper-dataset bicubic checks before SR3 smoke training

# %%
from pathlib import Path

ROOT = Path.cwd()
TRACK = ROOT
TRACK

# %%
commands = [
    "python scripts/evaluate_run.py --config configs/phase0_bicubic_ucmerced_smoke.yaml",
    "python scripts/evaluate_run.py --config configs/phase0_bicubic_aid_smoke.yaml",
    "python scripts/evaluate_run.py --config configs/phase0_bicubic_rsscn7_smoke.yaml",
    "python scripts/evaluate_run.py --config configs/phase0_bicubic_kaggle_control_smoke.yaml",
    "python scripts/train_baseline.py --config configs/phase1_sr3_smoke.yaml",
    "python scripts/evaluate_run.py --config configs/phase1_sr3_smoke.yaml --checkpoint artifacts/<run-name>/checkpoints/sr3_smoke.pt",
]
commands
